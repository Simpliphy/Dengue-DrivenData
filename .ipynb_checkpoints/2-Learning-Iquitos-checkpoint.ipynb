# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import HTML

# %matplotlib inline

# %%
# !tree
# Out:
# .
# ├── 1-Data-exploration.ipynb
# ├── 2-Learning.ipynb
# ├── 2-Learning-SanJuan-Copy1.ipynb
# ├── 2-Learning-SanJuan.ipynb
# ├── 2-Median Submission.ipynb
# ├── data_processing.py
# ├── dengue_features_test.csv
# ├── dengue_features_train.csv
# ├── dengue_labels_train.csv
# ├── Iquitos-plaza.jpg
# ├── median_as_prediction.csv
# ├── optimizationOfModels.py
# ├── __pycache__
# │   ├── data_processing.cpython-36.pyc
# │   └── optimizationOfModels.cpython-36.pyc
# ├── README.md
# ├── SanJuan-ElasticNet_Iquitos-RandomForest.csv
# ├── San_Juan-Puerto_Rico.JPG
# ├── SanJuan-RandomForest_Iquitos-RandomForest.csv
# └── submission_format.csv
#
# 1 directory, 19 files

# %% [markdown]
# # 1. Data import and processing

# %%
from data_processing import preprocess_data,split_time_series,preprocess_data_with_PCA

lag_step_for_SanJuan = 15
lag_step_for_Iquitos = 20

sj_features,sj_targets, iq_features, iq_targets = preprocess_data_with_PCA('dengue_features_train.csv',
                                    labels_path="dengue_labels_train.csv",
                                    lag_step_for_SanJuan = lag_step_for_SanJuan,
                                    lag_step_for_Iquitos = lag_step_for_Iquitos)

# %% [markdown]
# # 2. Training

# %%
test_set_ratio = 0.3 

X_sj_train, X_sj_test, y_sj_train, y_sj_test = split_time_series(sj_features, sj_targets, test_set_ratio)
X_iq_train, X_iq_test, y_iq_train, y_iq_test = split_time_series(iq_features, iq_targets, test_set_ratio)

# %% [markdown]
# ## 2.1 Optimization of parameters for San Juan

# %%
from optimizationOfModels import find_best_params_ElasticNet, find_best_params_RandomForest

# %%
parameters1_SanJuan = [10,20,50,100,200,300,500]
parameters2_SanJuan = [10,15,20,40]

param1_sj, param2_sj, scores__mean_absulute_error_sj = find_best_params_RandomForest(X_sj_train,
                                                                                 y_sj_train,
                                                                                 X_sj_test,
                                                                                 y_sj_test,
                                                                                 parameters1_SanJuan,
                                                                                 parameters2_SanJuan)
# Out:
# mean_absolute_error [n_estimators,max_depth]: mean absolute error
# mean_absolute_error [10,10]: 23.731466198037126
# mean_absolute_error [10,15]: 24.04486517794746
# mean_absolute_error [10,20]: 24.030855163781165
# mean_absolute_error [10,40]: 23.80711743772242
# mean_absolute_error [20,10]: 24.118876431414893
# mean_absolute_error [20,15]: 23.998959750000427
# mean_absolute_error [20,20]: 23.991241621600015
# mean_absolute_error [20,40]: 23.702135231316728
# mean_absolute_error [50,10]: 23.768017667417936
# mean_absolute_error [50,15]: 23.938439227369095
# mean_absolute_error [50,20]: 23.830579155099166
# mean_absolute_error [50,40]: 23.712455516014234
# mean_absolute_error [100,10]: 23.377590239447837
# mean_absolute_error [100,15]: 23.473252503261786
# mean_absolute_error [100,20]: 23.405264940606084
# mean_absolute_error [100,40]: 23.376014234875445
# mean_absolute_error [200,10]: 23.28727795749122
# mean_absolute_error [200,15]: 23.504631156515938
# mean_absolute_error [200,20]: 23.512757626138175
# mean_absolute_error [200,40]: 23.59405693950178
# mean_absolute_error [300,10]: 23.14794933883447
# mean_absolute_error [300,15]: 23.496026690273567
# mean_absolute_error [300,20]: 23.417739447551103
# mean_absolute_error [300,40]: 23.466820877817316
# mean_absolute_error [500,10]: 23.453222255767812
# mean_absolute_error [500,15]: 23.68589412569575
# mean_absolute_error [500,20]: 23.580657308782293
# mean_absolute_error [500,40]: 23.62435587188612
#
# -------------------------
# best_mean_absolute_error: 23.14794933883447
# n_estimators: 300
# max_depth: 10
# -------------------------

# %%
plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(scores__mean_absulute_error_sj, interpolation='nearest', cmap=plt.cm.hot_r)
plt.ylabel('alpha')
plt.xlabel('--')
plt.colorbar()
plt.yticks(np.arange(len(parameters1_SanJuan)), parameters1_SanJuan, rotation=45)
plt.xticks(np.arange(len(parameters2_SanJuan)), parameters2_SanJuan)
plt.title('Validation accuracy for San Juan')
plt.show()

# %% [markdown]
# ## 2.2 Optimization of parameters for Iquitos

# %%
parameters1_Iquitos = [10,20,50,100,200,300,500]
parameters2_Iquitos = [10,15,20,40]

param1_iq, param2_iq, scores__mean_absulute_error_iq = find_best_params_RandomForest(X_iq_train,
                                                                                 y_iq_train,
                                                                                 X_iq_test,
                                                                                 y_iq_test,
                                                                                 parameters1_Iquitos,
                                                                                 parameters2_Iquitos)
# Out:
# mean_absolute_error [n_estimators,max_depth]: mean absolute error
# mean_absolute_error [10,10]: 24.02597298814638
# mean_absolute_error [10,15]: 23.61732963102978
# mean_absolute_error [10,20]: 23.65071427879288
# mean_absolute_error [10,40]: 23.62491103202847
# mean_absolute_error [20,10]: 22.998971982008428
# mean_absolute_error [20,15]: 22.776098417142784
# mean_absolute_error [20,20]: 22.98533804895742
# mean_absolute_error [20,40]: 22.968861209964412
# mean_absolute_error [50,10]: 23.266751899038095
# mean_absolute_error [50,15]: 23.253807454468447
# mean_absolute_error [50,20]: 23.283583986799325
# mean_absolute_error [50,40]: 23.30220640569395
# mean_absolute_error [100,10]: 23.074183766009853
# mean_absolute_error [100,15]: 22.847714999046367
# mean_absolute_error [100,20]: 22.85218975185243
# mean_absolute_error [100,40]: 22.86074733096086
# mean_absolute_error [200,10]: 22.839409703101417
# mean_absolute_error [200,15]: 22.839582072717164
# mean_absolute_error [200,20]: 22.792524090269566
# mean_absolute_error [200,40]: 22.752330960854092
# mean_absolute_error [300,10]: 22.72483713849614
# mean_absolute_error [300,15]: 22.809007714113125
# mean_absolute_error [300,20]: 22.760635168617874
# mean_absolute_error [300,40]: 22.723024911032027
# mean_absolute_error [500,10]: 22.61572284498443
# mean_absolute_error [500,15]: 22.75164110328589
# mean_absolute_error [500,20]: 22.704746600664276
# mean_absolute_error [500,40]: 22.684505338078292
#
# -------------------------
# best_mean_absolute_error: 22.61572284498443
# n_estimators: 500
# max_depth: 10
# -------------------------

# %%
plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(scores__mean_absulute_error_iq, interpolation='nearest', cmap=plt.cm.hot_r)
plt.ylabel('n_estimators')
plt.xlabel('max_depth')
plt.colorbar()
plt.yticks(np.arange(len(parameters1_Iquitos)), parameters1_Iquitos, rotation=45)
plt.xticks(np.arange(len(parameters2_Iquitos)), parameters2_Iquitos)
plt.title('Validation accuracy for Iquitos')
plt.show()

# %% [markdown]
# ## 2.3 Final evaluation of models

# %%
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor

#regressor_sj = ElasticNet(alpha=param1_sj,
#                          l1_ratio=param2_sj)
regressor_sj = RandomForestRegressor(n_estimators=param1_sj,
                                     max_depth=param2_sj,
                                     criterion='mae',
                                     warm_start = True,
                                     random_state=0,
                                     n_jobs=8)

regressor_iq = RandomForestRegressor(n_estimators=param1_iq,
                                     max_depth=param2_iq,
                                     criterion='mse',
                                     warm_start = True,
                                     random_state=0,
                                     n_jobs=8)

# %%
regressor_sj.fit(X_sj_train,y_sj_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mae', max_depth=10,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=300, n_jobs=8, oob_score=False, random_state=0,
#            verbose=0, warm_start=True)

# %%
regressor_iq.fit(X_iq_train,y_iq_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=500, n_jobs=8, oob_score=False, random_state=0,
#            verbose=0, warm_start=True)

# %%
df_features_importance = pd.concat((pd.DataFrame(X_sj_train.columns, columns = ['variable']), 
           pd.DataFrame(regressor_sj.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]

df_features_importance.plot.bar(x=df_features_importance['variable'])

# %%
predictions_sj = regressor_sj.predict(X_sj_test)
predictions_iq = regressor_iq.predict(X_iq_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("For San Juan\n ")
print("mean_squared_error: {0}".format(mean_squared_error(y_sj_test, predictions_sj)))
print("mean_absolute_error: {0}".format(mean_absolute_error(y_sj_test, predictions_sj)))


df1 = pd.DataFrame({"predicted":predictions_sj,"actual":y_sj_test})

df1.plot()
plt.title('San Juan: predicted vs actual')
plt.xlabel('Time')
plt.legend()
# Out:
# For San Juan
#
# mean_squared_error: 1055.8507165480428
# mean_absolute_error: 25.563107947805456

# %%
print("\nFor Iquitos\n ")
print("mean_squared_error: {0}".format(mean_squared_error(y_iq_test, predictions_iq)))
print("mean_absolute_error: {0}".format(mean_absolute_error(y_iq_test, predictions_iq)))

df2 = pd.DataFrame({"predicted":predictions_iq,"actual":y_iq_test})

df2.plot()
plt.title('Iquitos: predicted vs actual')
plt.xlabel('Time')

plt.legend()
# Out:
# For Iquitos
#
# mean_squared_error: 897.8234774827047
# mean_absolute_error: 23.90921055581279

# %%
predictions_sj = regressor_sj.predict(sj_features)
predictions_iq = regressor_iq.predict(iq_features)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("For San Juan\n ")
print("mean_squared_error: {0}".format(mean_squared_error(sj_targets, predictions_sj)))
print("mean_absolute_error: {0}".format(mean_absolute_error(sj_targets, predictions_sj)))

df1 = pd.DataFrame({"predicted":predictions_sj,"actual":sj_targets})

df1.plot()
plt.title('San Juan: predicted vs actual')
plt.xlabel('Time')
plt.legend()
# Out:
# For San Juan
#
# mean_squared_error: 749.6378760179249
# mean_absolute_error: 17.909025997150994

# %%
print("\nFor Iquitos\n ")
print("mean_squared_error: {0}".format(mean_squared_error(iq_targets, predictions_iq)))
print("mean_absolute_error: {0}".format(mean_absolute_error(iq_targets, predictions_iq)))


df2 = pd.DataFrame({"predicted":predictions_iq,"actual":iq_targets})

df2.plot()
plt.title('Iquitos: predicted vs actual')
plt.xlabel('Time')

plt.legend()
# Out:
# For Iquitos
#
# mean_squared_error: 597.387567370591
# mean_absolute_error: 16.57898420016659

# %% [markdown]
# # 3. Submission

# %%
#regressor_sj.fit(sj_features,sj_targets)

# %%
#regressor_iq.fit(iq_features,iq_targets)

# %%
#sj_test, iq_test = preprocess_data('dengue_features_test.csv',
 #                                  lag_step_for_SanJuan = lag_step_for_SanJuan,
  #                                 lag_step_for_Iquitos = lag_step_for_Iquitos)


#sj_predictions = regressor_sj.predict(sj_test).astype(int)
#iq_predictions = regressor_iq.predict(iq_test).astype(int)

#submission = pd.read_csv("submission_format.csv",
 #                        index_col=[0, 1, 2])

#submission.total_cases = np.concatenate((sj_predictions, iq_predictions),axis=0)
#submission.to_csv("SanJuan-RandomForest_Iquitos-RandomForest.csv")
